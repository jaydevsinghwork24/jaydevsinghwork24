# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 =pd.read_csv("C:/Users/jaydev singh/Desktop/excel project/Maven_transaction1997-1998/MavenMarket_Transactions_1998.csv")
df2 =pd.read_csv("C:/Users/jaydev singh/Desktop/excel project/Maven_transaction1997-1998/MavenMarket_Transactions_1997.csv")
df3 =pd.read_csv("C:/Users/jaydev singh/Desktop/excel project/MavenMarket_Stores.csv")
df4 =pd.read_csv("C:/Users/jaydev singh/Desktop/excel project/MavenMarket_Regions.csv")
df5 =pd.read_csv("C:/Users/jaydev singh/Desktop/excel project/MavenMarket_Customers.csv")
df6 =pd.read_csv("C:/Users/jaydev singh/Desktop/excel project/MavenMarket_Products.csv")
df7 =pd.read_csv("C:/Users/jaydev singh/Desktop/excel project/MavenMarket_Calendar.csv")
df8 =pd.read_csv("C:/Users/jaydev singh/Desktop/excel project/MavenMarket_Returns_1997-1998.csv")

# %%
df1.head()
# Out:
#   transaction_date  stock_date  product_id  customer_id  store_id  quantity
# 0         1/1/1998  12/25/1997           4         2439        10         3
# 1         1/1/1998  12/28/1997          11         4284        10         3
# 2         1/1/1998  12/28/1997          12          534        10         3
# 3         1/1/1998  12/29/1997          14         9743        10         2
# 4         1/1/1998  12/27/1997          16         3608        10         3

# %%
df2.head()
# Out:
#   transaction_date  stock_date  product_id  customer_id  store_id  quantity
# 0         1/1/1997  12/31/1996         869         3449         6         5
# 1         1/1/1997  12/31/1996        1472         3449         6         3
# 2         1/1/1997  12/28/1996          76         3449         6         4
# 3         1/1/1997  12/26/1996         320         3449         6         3
# 4         1/1/1997  12/25/1996           4         3449         6         4

# %%
df3.head()
# Out:
#    store_id  region_id           store_type store_name store_street_address  \
# 0         1         28          Supermarket    Store 1       2853 Bailey Rd
# 1         2         78        Small Grocery    Store 2   5203 Catanzaro Way
# 2         3         76          Supermarket    Store 3   1501 Ramsey Circle
# 3         4         27  Gourmet Supermarket    Store 4     433 St George Dr
# 4         5          4        Small Grocery    Store 5   1250 Coggins Drive
#
#     store_city store_state store_country   store_phone first_opened_date  \
# 0     Acapulco    Guerrero        Mexico  262-555-5124          1/9/1982
# 1   Bellingham          WA           USA  605-555-8203          4/2/1970
# 2    Bremerton          WA           USA  509-555-1596         6/14/1959
# 3      Camacho   Zacatecas        Mexico  304-555-1474         9/27/1994
# 4  Guadalajara     Jalisco        Mexico  801-555-4324         9/18/1978
#
#   last_remodel_date  total_sqft  grocery_sqft
# ...

# %%
df4.head()
# Out:
#    region_id sales_district    sales_region
# 0          1  San Francisco    Central West
# 1          2    Mexico City  Mexico Central
# 2          3    Los Angeles      South West
# 3          4    Guadalajara     Mexico West
# 4          5      Vancouver     Canada West

# %%
df5.head()
# Out:
#    customer_id  customer_acct_num first_name  last_name    customer_address  \
# 0            1        87462024688      Sheri     Nowmer    2433 Bailey Road
# 1            2        87470586299    Derrick    Whelply  2219 Dewing Avenue
# 2            3        87475757600     Jeanne      Derry     7640 First Ave.
# 3            4        87500482201    Michael     Spence       337 Tosca Way
# 4            5        87514054179       Maya  Gutierrez     8668 Via Neruda
#
#   customer_city customer_state_province  customer_postal_code  \
# 0      Tlaxiaco                  Oaxaca                 15057
# 1         Sooke                      BC                 17172
# 2      Issaquah                      WA                 73980
# 3       Burnaby                      BC                 74674
# 4        Novato                      CA                 57355
#
#   customer_country  birthdate marital_status yearly_income gender  \
# ...

# %%
df5.dtypes
# Out:
# customer_id                 int64
# customer_acct_num           int64
# first_name                 object
# last_name                  object
# customer_address           object
# customer_city              object
# customer_state_province    object
# customer_postal_code        int64
# customer_country           object
# birthdate                  object
# marital_status             object
# yearly_income              object
# gender                     object
# total_children              int64
# num_children_at_home        int64
# education                  object
# acct_open_date             object
# member_card                object
# occupation                 object
# homeowner                  object
# dtype: object

# %%
# converting data type
df5['acct_open_date']=pd.to_datetime(df5['acct_open_date'])
df5['birthdate']=pd.to_datetime(df5['birthdate'])

# %%
df5.isnull().sum()
# Out:
# customer_id                0
# customer_acct_num          0
# first_name                 0
# last_name                  0
# customer_address           0
# customer_city              0
# customer_state_province    0
# customer_postal_code       0
# customer_country           0
# birthdate                  0
# marital_status             0
# yearly_income              0
# gender                     0
# total_children             0
# num_children_at_home       0
# education                  0
# acct_open_date             0
# member_card                0
# occupation                 0
# homeowner                  0
# dtype: int64

# %%
# giving priority to customer with homeowner and golden member
for i in df5.index:
    if df5.loc[i,'homeowner']=='Y' and df5.loc[i,'member_card']=='Golden':
        df5.loc[i,'Priority']='High'
    else:
        df5.loc[i,'Priority']='Standard'
        
df5.head()
# Out:
#    customer_id  customer_acct_num first_name  last_name    customer_address  \
# 0            1        87462024688      Sheri     Nowmer    2433 Bailey Road
# 1            2        87470586299    Derrick    Whelply  2219 Dewing Avenue
# 2            3        87475757600     Jeanne      Derry     7640 First Ave.
# 3            4        87500482201    Michael     Spence       337 Tosca Way
# 4            5        87514054179       Maya  Gutierrez     8668 Via Neruda
#
#   customer_city customer_state_province  customer_postal_code  \
# 0      Tlaxiaco                  Oaxaca                 15057
# 1         Sooke                      BC                 17172
# 2      Issaquah                      WA                 73980
# 3       Burnaby                      BC                 74674
# 4        Novato                      CA                 57355
#
#   customer_country  birthdate  ... yearly_income gender total_children  \
# ...

# %%
#creating a new column by joining two column
df5['Full_address']=df5['customer_address']+" "+df5['customer_country']
df5.head()
# Out:
#    customer_id  customer_acct_num first_name  last_name    customer_address  \
# 0            1        87462024688      Sheri     Nowmer    2433 Bailey Road
# 1            2        87470586299    Derrick    Whelply  2219 Dewing Avenue
# 2            3        87475757600     Jeanne      Derry     7640 First Ave.
# 3            4        87500482201    Michael     Spence       337 Tosca Way
# 4            5        87514054179       Maya  Gutierrez     8668 Via Neruda
#
#   customer_city customer_state_province  customer_postal_code  \
# 0      Tlaxiaco                  Oaxaca                 15057
# 1         Sooke                      BC                 17172
# 2      Issaquah                      WA                 73980
# 3       Burnaby                      BC                 74674
# 4        Novato                      CA                 57355
#
#   customer_country  birthdate  ... gender total_children num_children_at_home  \
# ...

# %%
# feching first 3 character then capitalizing it
for i in df5.index:
    df5.loc[i,'Country_code']=df5.loc[i,'customer_country'][:3].upper()
      
df5.head()
# Out:
#    customer_id  customer_acct_num first_name  last_name    customer_address  \
# 0            1        87462024688      Sheri     Nowmer    2433 Bailey Road
# 1            2        87470586299    Derrick    Whelply  2219 Dewing Avenue
# 2            3        87475757600     Jeanne      Derry     7640 First Ave.
# 3            4        87500482201    Michael     Spence       337 Tosca Way
# 4            5        87514054179       Maya  Gutierrez     8668 Via Neruda
#
#   customer_city customer_state_province  customer_postal_code  \
# 0      Tlaxiaco                  Oaxaca                 15057
# 1         Sooke                      BC                 17172
# 2      Issaquah                      WA                 73980
# 3       Burnaby                      BC                 74674
# 4        Novato                      CA                 57355
#
#   customer_country  birthdate  ... total_children num_children_at_home  \
# ...

# %%
df6.head()
# Out:
#    product_id product_brand                 product_name  product_sku  \
# 0           1    Washington       Washington Berry Juice  90748583674
# 1           2    Washington       Washington Mango Drink  96516502499
# 2           3    Washington  Washington Strawberry Drink  58427771925
# 3           4    Washington        Washington Cream Soda  64412155747
# 4           5    Washington         Washington Diet Soda  85561191439
#
#    product_retail_price  product_cost  product_weight  recyclable  low_fat
# 0                  2.85          0.94            8.39         NaN      NaN
# 1                  0.74          0.26            7.42         NaN      1.0
# 2                  0.83          0.40           13.10         1.0      1.0
# 3                  3.64          1.64           10.60         1.0      NaN
# 4                  2.19          0.77            6.66         1.0      NaN

# %%
df6[['recyclable','low_fat']]=df6[['recyclable','low_fat']].fillna(0)

# %%
# all unique product brand
dfa=df6['product_brand'].unique()
dfa
# Out:
# array(['Washington', 'Jeffers', 'Blue Label', 'Green Ribbon', 'King',
#        'Queen', 'Club', 'Red Spade', 'Blue Medal', 'Golden',
#        'Faux Products', 'Denny', 'Ship Shape', 'Robust', 'High Top',
#        'Tip Top', 'Best Choice', 'Choice', 'Medalist', 'Good', 'Great',
#        'Super', 'Excellent', 'Best', 'Better', 'Swell', 'ADJ',
#        'Black Tie', 'Carlson', 'Moms', 'Urban', 'Big Time', 'Steady',
#        'Red Wing', 'Quick', 'Dollar', 'Tell Tale', 'Kiwi', 'Fast',
#        'Atomic', 'Shady Lake', 'Walrus', 'Colony', 'Landslide', 'Token',
#        'Radius', 'Bravo', 'Applause', 'Prelude', 'Akron', 'Gorilla',
#        'Cutting Edge', 'Jumbo', 'Imagine', 'Consolidated', 'Cormorant',
#        'Footnote', 'Excel', 'Ebony', 'Curlew', 'Nationeel', 'Thresher',
#        'Monarch', 'Discover', 'Pearl', 'Fantastic', 'BBB Best',
#        'Fabulous', 'Special', 'Just Right', 'Big City', 'Symphony',
#        'James Bay', 'Even Better', 'American', 'National', 'PigTail',
# ...

# %%
df7.head()
# Out:
#        date
# 0  1/1/1997
# 1  1/2/1997
# 2  1/3/1997
# 3  1/4/1997
# 4  1/5/1997

# %%
df8.head()
# Out:
#   return_date  product_id  store_id  quantity
# 0    1/1/1997         250         6         1
# 1    1/1/1997         628         6         1
# 2    1/1/1997         869         6         1
# 3    1/2/1997         469        11         1
# 4    1/2/1997         532        23         2

# %%
df8['return_date']=pd.to_datetime(df8['return_date'])

# %%
# each year month wise return quantity
dfq= df8['quantity'].groupby(df8['return_date'].dt.strftime("%y, %m")).sum()
dfq.head()
# Out:
# return_date
# 97, 01    221
# 97, 02    191
# 97, 03    238
# 97, 04    186
# 97, 05    215
# Name: quantity, dtype: int64

# %%
df8.dtypes
# Out:
# return_date    datetime64[ns]
# product_id              int64
# store_id                int64
# quantity                int64
# dtype: object

# %%
#from dateutil.relativedelta import relativedelta
#from datetime import datetime

#one_month_ago = df8['return_date'] - relativedelta(months=1)
#one_month_ago

# %%
# merging the two transaction table into one
df9= pd.concat([df2,df1],axis=0,ignore_index=True)

# %%
df9.dtypes
# Out:
# transaction_date    object
# stock_date          object
# product_id           int64
# customer_id          int64
# store_id             int64
# quantity             int64
# dtype: object

# %%
df9['transaction_date']=pd.to_datetime(df9['transaction_date'])
df9['stock_date']=pd.to_datetime(df9['stock_date'])

# %%
q_store=df9['quantity'].groupby(df9['store_id']).sum()
dfthree=pd.merge(df3,q_store, how='left',left_on='store_id', right_on=q_store.index)
store_type=dfthree['quantity'].groupby(dfthree['store_type']).sum()
store_type.plot(kind='bar',xlabel='store_type', ylabel='Total selling')
plt.show()
# store type with their selling

# %%
# creating an empty column
dfb=pd.DataFrame()
dfb['customer_id']=df5['customer_id']

# %%
# finding total quantity of each coustomer
dfw=df9['quantity'].groupby(df9['customer_id']).sum()
dfw.head()
# Out:
# customer_id
# 3     89
# 5      2
# 6     57
# 8    122
# 9     39
# Name: quantity, dtype: int64

# %%
dfb=pd.merge(dfb,dfw, how='left',left_on='customer_id', right_on='customer_id')
dfb.rename(columns={'quantity':'total_quantity',},inplace= True)
dfb
# Out:
#        customer_id  total_quantity
# 0                1             NaN
# 1                2             NaN
# 2                3            89.0
# 3                4             NaN
# 4                5             2.0
# ...            ...             ...
# 10276        10277            98.0
# 10277        10278            80.0
# 10278        10279             NaN
# 10279        10280           128.0
# 10280        10281            93.0
#
# [10281 rows x 2 columns]

# %%
# not working
#dfb['total_quantity'].fillna('0')
#dfb

# %%
df7['date']=pd.to_datetime(df7['date'])

# %%
df7.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
# finding month name of date
df7["month_name"]=df7['date'].dt.strftime("%B")

# finding day name of date
df7["day_name"]=df7['date'].dt.strftime("%A")

# finding year of date
df7["year"]=df7['date'].dt.year
df7.head()
# Out:
#         date month_name   day_name  year
# 0 1997-01-01    January  Wednesday  1997
# 1 1997-01-02    January   Thursday  1997
# 2 1997-01-03    January     Friday  1997
# 3 1997-01-04    January   Saturday  1997
# 4 1997-01-05    January     Sunday  1997

# %%
# total quantity sold in both year
dfa=df9.groupby(df9['transaction_date'].dt.strftime('%Y'))['quantity'].sum()
dfa
# Out:
# transaction_date
# 1997    266773
# 1998    566716
# Name: quantity, dtype: int64

# %%
df3.insert(2,"total_return", " ")

# %%
# calcuating total return from each store
for i in df3.index:
    df3.loc[i,'total_return']=0
    for j in df8.index:
        if df3.loc[i,'store_id']==df8.loc[j, 'store_id']:
            df3.loc[i,'total_return']=df3.loc[i,'total_return']+df8.loc[j,'quantity']

# %%
df3.head()
# Out:
#    store_id  region_id total_return           store_type store_name  \
# 0         1         28          267          Supermarket    Store 1
# 1         2         78            0        Small Grocery    Store 2
# 2         3         76          496          Supermarket    Store 3
# 3         4         27          255  Gourmet Supermarket    Store 4
# 4         5          4            0        Small Grocery    Store 5
#
#   store_street_address   store_city store_state store_country   store_phone  \
# 0       2853 Bailey Rd     Acapulco    Guerrero        Mexico  262-555-5124
# 1   5203 Catanzaro Way   Bellingham          WA           USA  605-555-8203
# 2   1501 Ramsey Circle    Bremerton          WA           USA  509-555-1596
# 3     433 St George Dr      Camacho   Zacatecas        Mexico  304-555-1474
# 4   1250 Coggins Drive  Guadalajara     Jalisco        Mexico  801-555-4324
#
#   first_opened_date last_remodel_date  total_sqft  grocery_sqft
# ...

# %%
dft=df9.groupby(df9['product_id'])['quantity'].sum()
dft.head()
# Out:
# product_id
# 1    245
# 2    471
# 3    447
# 4    459
# 5    440
# Name: quantity, dtype: int64

# %%
#dft.tail()

# %%
dfr=df8.groupby(df8['product_id'])['quantity'].sum()
dfr.head()
# Out:
# product_id
# 1    3
# 2    4
# 3    9
# 4    7
# 5    1
# Name: quantity, dtype: int64

# %%
#dfr.rename({'quantity': 'total_return'}, inplace=True)
#dfr.head()

# %%
dfcalc=pd.DataFrame()
dfcalc.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dfcalc['product_id']=df6['product_id']

# %%
dfcalc=pd.merge(dfcalc,dft, how='left',left_on='product_id', right_on=dft.index)
dfcalc.rename(columns={'quantity': 'total_transaction',}, inplace=True)
dfcalc.head()
# Out:
#    product_id  total_transaction
# 0           1              245.0
# 1           2              471.0
# 2           3              447.0
# 3           4              459.0
# 4           5              440.0

# %%
dfcalc=pd.merge(dfcalc,dfr, how='left',left_on='product_id', right_on=dfr.index)
dfcalc.rename(columns={'quantity': 'total_return',}, inplace=True)
dfcalc.head()
# Out:
#    product_id  total_transaction  total_return
# 0           1              245.0           3.0
# 1           2              471.0           4.0
# 2           3              447.0           9.0
# 3           4              459.0           7.0
# 4           5              440.0           1.0

# %%
dfcalc=pd.merge(dfcalc,df6[['product_retail_price','product_cost']], how='left', left_on=dfcalc['product_id'], right_on=df6['product_id'])
dfcalc.head()
# Out:
#    key_0  product_id  total_transaction  total_return  product_retail_price  \
# 0      1           1              245.0           3.0                  2.85
# 1      2           2              471.0           4.0                  0.74
# 2      3           3              447.0           9.0                  0.83
# 3      4           4              459.0           7.0                  3.64
# 4      5           5              440.0           1.0                  2.19
#
#    product_cost
# 0          0.94
# 1          0.26
# 2          0.40
# 3          1.64
# 4          0.77

# %%
dfcalc.fillna(0)
# Out:
#       key_0  product_id  total_transaction  total_return  \
# 0         1           1              245.0           3.0
# 1         2           2              471.0           4.0
# 2         3           3              447.0           9.0
# 3         4           4              459.0           7.0
# 4         5           5              440.0           1.0
# ...     ...         ...                ...           ...
# 1555   1556        1556              566.0           4.0
# 1556   1557        1557              560.0           4.0
# 1557   1558        1558              453.0           2.0
# 1558   1559        1559              240.0           3.0
# 1559   1560        1560                0.0           0.0
#
#       product_retail_price  product_cost
# 0                     2.85          0.94
# 1                     0.74          0.26
# 2                     0.83          0.40
# 3                     3.64          1.64
# 4                     2.19          0.77
# ...

# %%
for i in dfcalc.index:
    dfcalc.loc[i,'total_cost']=dfcalc.loc[i,'total_transaction']*dfcalc.loc[i,'product_cost']
    dfcalc.loc[i,'expected_revenue']=dfcalc.loc[i,'total_transaction']*dfcalc.loc[i,'product_retail_price']
    dfcalc.loc[i,'total_loss']=dfcalc.loc[i,'total_return']*dfcalc.loc[i,'product_cost']
    dfcalc.loc[i,'profit']=dfcalc.loc[i,'expected_revenue']-dfcalc.loc[i,'total_loss']
    
dfcalc
# Out:
#       key_0  product_id  total_transaction  total_return  \
# 0         1           1              245.0           3.0
# 1         2           2              471.0           4.0
# 2         3           3              447.0           9.0
# 3         4           4              459.0           7.0
# 4         5           5              440.0           1.0
# ...     ...         ...                ...           ...
# 1555   1556        1556              566.0           4.0
# 1556   1557        1557              560.0           4.0
# 1557   1558        1558              453.0           2.0
# 1558   1559        1559              240.0           3.0
# 1559   1560        1560                NaN           NaN
#
#       product_retail_price  product_cost  total_cost  expected_revenue  \
# 0                     2.85          0.94      230.30            698.25
# 1                     0.74          0.26      122.46            348.54
# ...

# %%
#total_cost=dfcalc['total_transaction']*dfcalc['product_cost']
t_cost=dfcalc['total_cost'].sum()
e_revenue=dfcalc['expected_revenue'].sum()
t_loss=dfcalc['total_loss'].sum()
profit=dfcalc['profit'].sum()
print("total_cost=",t_cost)
print("total_loss=",t_loss)
print("expected_revenue=",e_revenue)
print("profit=",profit)
# Out:
# total_cost= 711727.66
# total_loss= 7038.08
# expected_revenue= 1764546.44
# profit= 1735858.18

# %%
# findind if customer and store belong to same city

df9['Matching_city'] = ['Yes' if df5.loc[df5['customer_id'] == c_id, 'customer_city'].values[0] == df3.loc[df3['store_id'] == s_id, 'store_city'].values[0] else 'No' for c_id, s_id in zip(df9['customer_id'], df9['store_id'])]
df9
# Out:
#        transaction_date stock_date  product_id  customer_id  store_id  \
# 0            1997-01-01 1996-12-31         869         3449         6
# 1            1997-01-01 1996-12-31        1472         3449         6
# 2            1997-01-01 1996-12-28          76         3449         6
# 3            1997-01-01 1996-12-26         320         3449         6
# 4            1997-01-01 1996-12-25           4         3449         6
# ...                 ...        ...         ...          ...       ...
# 269715       1998-12-30 1998-12-29        1521         7197        11
# 269716       1998-12-30 1998-12-23        1536         5223        10
# 269717       1998-12-30 1998-12-23        1542         8077        10
# 269718       1998-12-30 1998-12-28        1544         4485        10
# 269719       1998-12-30 1998-12-29        1549         5223        10
#
#         quantity Matching_city
# 0              5            No
# 1              3            No
# ...
