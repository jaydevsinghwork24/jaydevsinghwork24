# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/jaydev singh/Desktop/car.csv")

# %%
x=df[(df['MSRP']>=38000) & (df['MSRP']<=40000)]
x
# Out:
#                Make                  Model  Engine HP  Engine Cylinders  \
# 7               BMW               1 Series      230.0               6.0
# 10              BMW               1 Series      320.0               6.0
# 42             Audi                    200      217.0               5.0
# 54              BMW  3 Series Gran Turismo      300.0               6.0
# 100   Mercedes-Benz              300-Class      148.0               6.0
# ...             ...                    ...        ...               ...
# 3917         Suzuki                 Verona      155.0               6.0
# 3920         Nissan             Versa Note      109.0               4.0
# 3923         Nissan                  Versa      109.0               4.0
# 3992          Volvo                   XC60      300.0               6.0
# 3993          Volvo                   XC60      302.0               4.0
#
#      Transmission Type      Driven_Wheels  Number of Doors  Vehicle Style  \
# ...

# %%
x=df['city mpg'].nlargest(10).sort_values(ascending=False)

# %%
typ=df[(df['Vehicle Style']=='Sedan')&(df['Transmission Type']=='MANUAL')&(df['Number of Doors']==4)]
typ
# Out:
#                Make      Model  Engine HP  Engine Cylinders Transmission Type  \
# 11             Audi        100      172.0               6.0            MANUAL
# 13             Audi        100      172.0               6.0            MANUAL
# 15             Audi        100      172.0               6.0            MANUAL
# 16             Audi        100      172.0               6.0            MANUAL
# 20    Mercedes-Benz  190-Class      130.0               4.0            MANUAL
# ...             ...        ...        ...               ...               ...
# 3930          Acura      Vigor      176.0               5.0            MANUAL
# 3953         Subaru        WRX      305.0               4.0            MANUAL
# 3955         Subaru        WRX      268.0               4.0            MANUAL
# 3956         Subaru        WRX      268.0               4.0            MANUAL
# 4051         Toyota   Yaris iA      106.0               4.0            MANUAL
#
# ...
